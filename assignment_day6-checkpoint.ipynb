# %%
import numpy as np
import pandas as pd
import os
import pickle 
from sklearn.tree import DecisionTreeClassifier 
from sklearn.metrics import accuracy_score ,confusion_matrix
from sklearn.tree import DecisionTreeClassifier 
from sklearn.ensemble import RandomForestClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
import warnings
warnings.filterwarnings("ignore")
from sklearn.model_selection import train_test_split
from os.path import isfile

# %%
data = pd.read_csv('diabetes.csv')
data.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
data.dtypes
# Out:
# Pregnancies                   int64
# Glucose                       int64
# BloodPressure                 int64
# SkinThickness                 int64
# Insulin                       int64
# BMI                         float64
# DiabetesPedigreeFunction    float64
# Age                           int64
# Outcome                       int64
# dtype: object

# %%
X = data.drop(columns='Outcome')
y = data['Outcome']

# %%
model = GaussianNB()
file_name = 'diabetes_model.pickle'
top_acc = 0
if not isfile(file_name):
    for i in range(50):
        X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)
        
        model.fit(X_train, y_train)        

        predictions = model.predict(X_test)
        acc = accuracy_score(y_test, predictions)
        print('Current Accuracy : ', acc)
        if acc > top_acc:
            top_acc = acc
            with open(file_name, 'wb') as file:
                pickle.dump(model, file)
            
else:
    with open(file_name, 'rb') as file:
            model = pickle.load(file)
# Out:
# Current Accuracy :  0.7662337662337663
# Current Accuracy :  0.7142857142857143
# Current Accuracy :  0.7077922077922078
# Current Accuracy :  0.7337662337662337
# Current Accuracy :  0.7662337662337663
# Current Accuracy :  0.7662337662337663
# Current Accuracy :  0.7467532467532467
# Current Accuracy :  0.7597402597402597
# Current Accuracy :  0.8116883116883117
# Current Accuracy :  0.6493506493506493
# Current Accuracy :  0.7402597402597403
# Current Accuracy :  0.7077922077922078
# Current Accuracy :  0.7597402597402597
# Current Accuracy :  0.7727272727272727
# Current Accuracy :  0.8051948051948052
# Current Accuracy :  0.7337662337662337
# Current Accuracy :  0.7402597402597403
# Current Accuracy :  0.8311688311688312
# Current Accuracy :  0.8116883116883117
# Current Accuracy :  0.7012987012987013
# Current Accuracy :  0.7467532467532467
# Current Accuracy :  0.7207792207792207
# Current Accuracy :  0.7792207792207793
# Current Accuracy :  0.7467532467532467
# Current Accuracy :  0.7467532467532467
# Current Accuracy :  0.8051948051948052
# Current Accuracy :  0.7922077922077922
# Current Accuracy :  0.7727272727272727
# Current Accuracy :  0.7597402597402597
# Current Accuracy :  0.7272727272727273
# Current Accuracy :  0.7142857142857143
# Current Accuracy :  0.7467532467532467
# Current Accuracy :  0.7597402597402597
# Current Accuracy :  0.7662337662337663
# Current Accuracy :  0.7792207792207793
# Current Accuracy :  0.7207792207792207
# Current Accuracy :  0.7597402597402597
# Current Accuracy :  0.7207792207792207
# Current Accuracy :  0.7532467532467533
# Current Accuracy :  0.8441558441558441
# Current Accuracy :  0.7532467532467533
# Current Accuracy :  0.7792207792207793
# Current Accuracy :  0.7142857142857143
# Current Accuracy :  0.7792207792207793
# Current Accuracy :  0.6883116883116883
# Current Accuracy :  0.7402597402597403
# Current Accuracy :  0.7272727272727273
# Current Accuracy :  0.7077922077922078
# Current Accuracy :  0.8051948051948052
# Current Accuracy :  0.7012987012987013

# %%
print('''
                                    Diabetes Classifier
                                ---------------------------
                    Please enter the characteristics of the patient you want to predict.
                                        
                                            NOTICE:
                    Please make sure that you've read the data description clearly before you enter any values.
                    
                -------------------------------------------------------------------------------------------------
                    Pregnancies: Number of times pregnant
                    Glucose: Plasma glucose concentration a 2 hours in an oral glucose tolerance test
                    BloodPressure: Diastolic blood pressure (mm Hg)
                    SkinThickness: Triceps skin fold thickness (mm)
                    Insulin: 2-Hour serum insulin (mu U/ml)
                    BMI: Body mass index (weight in kg/(height in m)^2)
                    DiabetesPedigreeFunction: Diabetes pedigree function
                    Age: Age (years)
                    Outcome: Class variable (0 or 1)
''')


pregnancies = int(input("Enter number of times pregnant:"))
glucose = int(input("Enter concentration of Glucose:"))
blood_pressure = int(input("Enter Blood Pressure          :"))
skin_thickness = int(input("Enter Skin Thickness          :"))
insulin = int(input("Enter Insulin                :"))
bmi = float(input("Enter BMI (Body Mass Index    :"))
diabetes_pedigree_function = float(input("Enter Diabetes Pedigree value : "))
age = int(input("Enter age of the patient      : "))

features_of_patient = np.array([pregnancies, glucose, blood_pressure, skin_thickness , insulin , bmi , diabetes_pedigree_function , age])
predictions = model.predict([features_of_patient])
print('------------------------')
print('The prediction is     : ' , predictions)
# Out:
#                                     Diabetes Classifier
#                                 ---------------------------
#                     Please enter the characteristics of the patient you want to predict.
#
#                                             NOTICE:
#                     Please make sure that you've read the data description clearly before you enter any values.
#
#                 -------------------------------------------------------------------------------------------------
#                     Pregnancies: Number of times pregnant
#                     Glucose: Plasma glucose concentration a 2 hours in an oral glucose tolerance test
#                     BloodPressure: Diastolic blood pressure (mm Hg)
#                     SkinThickness: Triceps skin fold thickness (mm)
#                     Insulin: 2-Hour serum insulin (mu U/ml)
#                     BMI: Body mass index (weight in kg/(height in m)^2)
#                     DiabetesPedigreeFunction: Diabetes pedigree function
#                     Age: Age (years)
#                     Outcome: Class variable (0 or 1)
#
# Enter number of times pregnant:9
# Enter concentration of Glucose:89
# Enter Blood Pressure         :68
# Enter Skin Thickness         :25
# Enter Insulin                  :70
# Enter BMI (Body Mass Index   :24.2
# Enter Diabetes Pedigree value : 0.305
# Enter age of the patient    : 50
# ------------------------
# The prediction is     :  [0]
